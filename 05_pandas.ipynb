# %% [markdown]
# [pandas documentation](https://pydata.org/)

# %%
pip list
# Out:
# Package             Version
# ------------------- -------------
# asttokens           3.0.0
# attrs               21.2.0
# Automat             20.2.0
# awscli              1.35.0
# Babel               2.8.0
# bcrypt              3.2.0
# blinker             1.4
# botocore            1.35.34
# certifi             2020.6.20
# chardet             4.0.0
# click               8.0.3
# cloud-init          24.4
# colorama            0.4.6
# comm                0.2.2
# command-not-found   0.3
# configobj           5.0.6
# constantly          15.1.0
# cryptography        3.4.8
# dbus-python         1.2.18
# debugpy             1.8.12
# decorator           5.1.1
# distro              1.7.0
# distro-info         1.1+ubuntu0.2
# docutils            0.16
# exceptiongroup      1.2.2
# executing           2.2.0
# httplib2            0.20.2
# hyperlink           21.0.0
# idna                3.3
# importlib-metadata  4.6.4
# incremental         21.3.0
# ipykernel           6.29.5
# ...

# %%
import pandas as pd

# %%
# data frame
df = pd.read_csv('./data-files/california_housing_test.csv')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df["total_rooms"]
# Out:
# 0       3885.0
# 1       1510.0
# 2       3589.0
# 3         67.0
# 4       1241.0
#          ...
# 2995    1450.0
# 2996    5257.0
# 2997     956.0
# 2998      96.0
# 2999    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %%
df.total_bedrooms
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
df.total_bedrooms[0]
# Out:
# np.float64(661.0)
